# %% [markdown]
# # Script to pull metadata from Wikidata
#
# Throughout the script I refer to "Wikidata" but this could be used for any Wikibase instance.

# %% [markdown]
# ## Configuration section
#
# Import modules, set values, and define functions

# %%
# acquire-wikidata-metadata.ipynb This is part of the VandyCite project https://www.wikidata.org/wiki/Wikidata:WikiProject_VandyCite
# (c) 2020 Vanderbilt University. This program is released under a GNU General Public License v3.0 http://www.gnu.org/licenses/gpl-3.0
# Author: Steve Baskauf 2020-09-05

import vb_common_code as vbc
from pathlib import Path
import requests
from time import sleep
import json

'''
import csv
import math
from fuzzywuzzy import fuzz # fuzzy logic matching
from fuzzywuzzy import process
import xml.etree.ElementTree as et # library to traverse XML tree
import urllib
import datetime
import string
import copy # import the copy module from the standard library
'''

sparql_sleep = 0.1 # number of seconds to wait between queries to SPARQL endpoint
home = str(Path.home()) # gets path to home directory; supposed to work for both Win and Mac
data_path = home + '/divinity-law/'
item_source_csv = 'identified-journals.csv'

endpoint = 'https://query.wikidata.org/sparql'
accept_media_type = 'application/json'

# known_name_strings_path = home + '/divinity-law/known-name-strings.csv'
# wikidata_article_matches_path  = home + '/divinity-law/wikidata-article-matches.csv'
# duplicate_works_path  = home + '/divinity-law/duplicate-works.csv'
# journals_path = home + '/divinity-law/journals.csv'
# employerQId = 'Q29052' # Vanderbilt University
# testRatio = 90 # similarity required for a potential match of a generic wikidata match
# journalTestRatio = 94 # similarity required for a potential match of a generic wikidata match


def generate_header_dictionary(accept_media_type):
    user_agent_header = 'VanderDiv/0.1 (https://github.com/HeardLibrary/linked-data/tree/master/publications/divinity-law; mailto:steve.baskauf@vanderbilt.edu)'
    requestHeaderDictionary = {
        'Accept' : accept_media_type,
        'Content-Type': 'application/sparql-query',
        'User-Agent': user_agent_header
    }
    return requestHeaderDictionary

requestheader = generate_header_dictionary(accept_media_type)

# extracts the qNumber from a Wikidata IRI
def extract_qnumber(iri):
    # pattern is http://www.wikidata.org/entity/Q6386232
    pieces = iri.split('/')
    return pieces[4]

# extracts the UUID and qId from a statement IRI
def extract_statement_uuid(iri):
    # pattern is http://www.wikidata.org/entity/statement/Q7552806-8B88E0CA-BCC8-49D5-9AC2-F1755464F1A2
    pieces = iri.split('/')
    statement_id = pieces[5]
    pieces = statement_id.split('-')
    return pieces[1] + '-' + pieces[2] + '-' + pieces[3] + '-' + pieces[4] + '-' + pieces[5], pieces[0]

'''
# extracts the reference hash from a reference IRI
def extract_reference_hash(iri):
    # pattern is http://www.wikidata.org/entity/Q6386232
    pieces = iri.split('/')
    return pieces[5]
'''
'''
# read from a CSV file beginning with a bit order mark (BOM) into a list of dictionaries
# Change encoding type to utf-8-sig instead of utf-8 to fix this
def read_dict_bom(filename):
    with open(filename, 'r', newline='', encoding='utf-8-sig') as fileObject: 
        dictObject = csv.DictReader(fileObject)
        array = []
        for row in dictObject:
            array.append(row)
    return array

def reverse_names(nameLastFirst):
    nameLastFirst = nameLastFirst.strip()
    nameParts = nameLastFirst.split(',')
    if len(nameParts) < 2: # name probably isn't reversed
        name = nameLastFirst.strip()
    else:
        firstName = nameParts[1].strip()
        lastName = nameParts[0].strip()
        name = firstName + ' ' + lastName

        if len(nameParts) > 2:
            suffix = nameParts[2].strip()
        else:
            suffix = ''
        name = firstName + ' ' + lastName
        if suffix == 'Jr.':
            name += ', Jr.'
        elif suffix == 'Jr':
            name += ', Jr.'
        elif suffix == '':
            pass
        elif suffix == 'II':
            name += ' ' + suffix
        elif suffix == 'III':
            name += ' ' + suffix
        elif suffix == 'IV':
            name += ' ' + suffix
        elif suffix == 'V':
            name += ' ' + suffix
    return name
'''
# Out:
# "\n# read from a CSV file beginning with a bit order mark (BOM) into a list of dictionaries\n# Change encoding type to utf-8-sig instead of utf-8 to fix this\ndef read_dict_bom(filename):\n    with open(filename, 'r', newline='', encoding='utf-8-sig') as fileObject: \n        dictObject = csv.DictReader(fileObject)\n        array = []\n        for row in dictObject:\n            array.append(row)\n    return array\n\ndef reverse_names(nameLastFirst):\n    nameLastFirst = nameLastFirst.strip()\n    nameParts = nameLastFirst.split(',')\n    if len(nameParts) < 2: # name probably isn't reversed\n        name = nameLastFirst.strip()\n    else:\n        firstName = nameParts[1].strip()\n        lastName = nameParts[0].strip()\n        name = firstName + ' ' + lastName\n\n        if len(nameParts) > 2:\n            suffix = nameParts[2].strip()\n        else:\n            suffix = ''\n        name = firstName + ' ' + lastName\n        if suffix == 'Jr.':\n            name += ', Jr.'\n        elif suffix == 'Jr':\n            name += ', Jr.'\n        elif suffix == '':\n            pass\n        elif suffix == 'II':\n            name += ' ' + suffix\n        elif suffix == 'III':\n            name += ' ' + suffix\n        elif suffix == 'IV':\n            name += ' ' + suffix\n        elif suffix == 'V':\n            name += ' ' + suffix\n    return name\n"

# %% [markdown]
# ## Load list of items from file
#
# The CSV has a header row with column headers: `qid` and `label`. The `qid` column contains the Wikidata Q identifiers for each item. The `label` column contains the label, which isn't necessarily the label in Wikidata, but provides a way for humans to recognize the item.

# %%
# Load item data from csv
print('loading item data from file')
filename = data_path + item_source_csv
items = vbc.readDict(filename)

# Create VALUES list for journals
item_qids = ''
for item in items:
    item_qids += 'wd:' + item['qid'] + '\n'
# remove trailing newline
item_qids = item_qids[:len(item_qids)-1]

# create properties dictionary
prop_list = [
    {'pid': 'P31', 'variable': 'instance_of', 'value_type': 'item'},
    {'pid': 'P1476', 'variable': 'title', 'value_type': 'string'},
    {'pid': 'P407', 'variable': 'language_of_work', 'value_type': 'item'},
    {'pid': 'P495', 'variable': 'country_of_origin', 'value_type': 'item'},
    {'pid': 'P123', 'variable': 'publisher', 'value_type': 'item'},
    {'pid': 'P571', 'variable': 'inception', 'value_type': 'date'},
    {'pid': 'P2669', 'variable': 'discontinued_date', 'value_type': 'item'},
    {'pid': 'P856', 'variable': 'official_website', 'value_type': 'uri'},
    {'pid': 'P155', 'variable': 'follows', 'value_type': 'item'},
    {'pid': 'P156', 'variable': 'followed_by', 'value_type': 'item'},
    {'pid': 'P921', 'variable': 'main_subject', 'value_type': 'item'},
    {'pid': 'P2896', 'variable': 'publication_interval', 'value_type': 'decimal'},
    {'pid': 'P236', 'variable': 'issn', 'value_type': 'string'}
]

#print(item_qids)
# Out:
# loading item data from file

# %% [markdown]
# This cell is to find out what properties are used by references given for the statement properties above and the items in the list.

# %%
for property in prop_list:
    print('*', property['pid'], property['variable'])
    query = '''select distinct ?gprop ?prop_label where {
    '''
    query += '''
      VALUES ?qid
    {
    ''' + item_qids + '''
    }

    '''
    query += '?qid p:' + property['pid'] + ''' ?issn_statement.
    # ?issn_statement prov:wasDerivedFrom ?reference.
    # ?reference ?prop ?value.
    # ?gprop wikibase:reference ?prop.
    # ?gprop rdfs:label ?prop_label.
    filter(lang(?prop_label)='en')
    }'''
    #print(query)
    
    # send request to Wikidata Query Service
    response = requests.post(endpoint, data=query, headers=requestheader)
    data = response.json()

    # extract the values from the response JSON
    results = data['results']['bindings']
    #print(json.dumps(results, indent = 2))
    for result in results:
        print(extract_qnumber(result['gprop']['value']), result['prop_label']['value'])
    print()
    sleep(sparql_sleep)
# Out:
# * P31 instance_of
# P236 ISSN
# P143 imported from Wikimedia project
# P248 stated in
# P813 retrieved
# P1683 quotation
#
# * P1476 title
# P143 imported from Wikimedia project
# P236 ISSN
# P248 stated in
#
# * P407 language_of_work
# P143 imported from Wikimedia project
# P248 stated in
# P854 reference URL
# P813 retrieved
# P887 based on heuristic
# P4656 Wikimedia import URL
#
# * P495 country_of_origin
# P143 imported from Wikimedia project
# P248 stated in
# P854 reference URL
# P4656 Wikimedia import URL
#
# * P123 publisher
# P143 imported from Wikimedia project
# P236 ISSN
# P248 stated in
# P813 retrieved
# P854 reference URL
# P4656 Wikimedia import URL
#
# * P571 inception
# P143 imported from Wikimedia project
# P248 stated in
# P854 reference URL
# P4327 BHL bibliography ID
# P1476 title
#
# * P2669 discontinued_date
#
# * P856 official_website
# P143 imported from Wikimedia project
# P813 retrieved
# P4656 Wikimedia import URL
# P854 reference URL
#
# * P155 follows
#
# * P156 followed_by
#
# * P921 main_subject
# P143 imported from Wikimedia project
# P248 stated in
# P4656 Wikimedia import URL
#
# * P2896 publication_interval
# P813 retrieved
# P854 reference URL
#
# * P236 issn
# P143 imported from Wikimedia project
# P248 stated in
# P813 retrieved
# P854 reference URL
# P4327 BHL bibliography ID

# %% [markdown]
# ## Create query to get the statement UUID and value
#
# SPARQL query to be sent to the Wikidata Query Service (WDQS)

# %%
property = prop_list[2]

# create a string for the query
query = '''
select distinct ?qid '''

query += '?' + property['variable'] + '_value '
query += '?' + property['variable'] + '_statement '

query += 'where {'

query += '''
  VALUES ?qid
{
''' + item_qids + '''
}

'''


query += '?qid wdt:' + property['pid'] + ' ?' + property['variable'] + '_value.\n'
query += '?qid p:' + property['pid'] + ' ?' + property['variable'] + '_statement.\n'
query += '}'

#print(query)

# %% [markdown]
# Send the query to the WDQS and extract the results from the returned JSON

# %%
# Send SPARQL query to the Wikidata Query Service
print('retrieving data from Wikidata')

# send request to Wikidata Query Service
response = requests.post(endpoint, data=query, headers=requestheader)
data = response.json()

# extract the values from the response JSON
results = data['results']['bindings']
#print(json.dumps(results, indent = 2))
# Out:
# retrieving data from Wikidata

# %% [markdown]
# Extract the qids, values, and statement UUIDs from the response data and store in a list of dicts (`statements_list`). Note: the `extract_statement_uuid()` function returns `uuid`,`qid` extracted from the statement IRI, so they have to be re-assembled to make the statement identifier: *qid*-*UUID*.

# %%
statements_list = [] # create list of data for statements, not really used for anything yet
statement_uuids = '' # create VALUES list for statmements
for result in results:
    row_dict = {}
    row_dict = {'qid': extract_qnumber(result['qid']['value'])}

    if property['value_type'] == 'item':
        # remove wd: 'http://www.wikidata.org/entity/'
        value = extract_qnumber(result[property['variable'] + '_value']['value'])
    else:
        value = result[property['variable'] + '_value']['value']
    row_dict[property['variable'] + '_value'] = value
    uuid, temp_qid = extract_statement_uuid(result[property['variable'] + '_statement']['value'])
    row_dict[property['variable'] + '_statement'] = uuid
    statement_uuids += 'wds:' + temp_qid + '-' + uuid + '\n'
    statements_list.append(row_dict)

# remove trailing newline
statement_uuids = statement_uuids[:len(statement_uuids)-1]

#print(statement_uuids)
#print(statements_list)

# %% [markdown]
# I used this query:
# ```
# select distinct ?gprop ?prop_label where {
#      VALUES ?id
#     {
# wd:Q7311312
# wd:Q4984286
# wd:Q15749660
# etc.
#     }
# ?id p:P236 ?issn_statement.
# ?issn_statement prov:wasDerivedFrom ?reference.
# ?reference ?prop ?value.
# ?gprop wikibase:reference ?prop.
# ?gprop rdfs:label ?prop_label.
# filter(lang(?prop_label)='en')
# }
# ```
# to find out what reference properties were in use in the journals of interest. They were:
#
# ```
# gprop   prop_label
# wd:P143  imported from Wikimedia project
# wd:P248  stated in
# wd:P813  retrieved
# wd:P854  reference URL
# wd:P4327 BHL bibliography ID
# ```
# The only Wikimedia project they were imported from was Wikipedia, so not a useful one to track. I don't think BHL ID is either, so that leaves P248, P813, and P845 as the useful ones to track.

# %%
# create a string for the query
query = 'select distinct ?label ?' + property['variable'] + ' ?statement ?reference ?statedIn ?refUrl ?retrDate ?retrPrecision where {'

query += '''
  VALUES ?statement
{
''' + statement_uuids + '''
}

'''
query += '''
# ?statement ps:''' + property['pid'] + ' ?' + property['variable'] + '''.
# ?qid p:''' + property['pid'] + ''' ?statement.
# ?qid rdfs:label ?label.
filter(lang(?label)='en')
optional{
# ?statement prov:wasDerivedFrom ?reference.
# ?reference pr:P248 ?statedIn.
}
optional{
# ?statement prov:wasDerivedFrom ?reference.
# ?reference pr:P854 ?refUrl.
}
optional{
# ?statement prov:wasDerivedFrom ?reference.
# ?reference prv:P813 ?retrievedNode.
# ?retrievedNode wikibase:timeValue ?retrDate.
# ?retrievedNode wikibase:timePrecision ?retrPrecision.
}
}'''

print(query)
# Out:
# select distinct ?label ?instance_of ?statement ?reference ?statedIn ?refUrl ?retrDate ?retrPrecision where {
#   VALUES ?statement
# {
# wds:Q8075881-1ECF040F-D49A-4206-AC3B-DEAF44E76E76
# wds:Q8075881-91645C5B-2728-4E8E-B1DD-204B6F3D9790
# wds:Q8075881-BCFF5533-57BF-4A6D-90F2-936DA8AE2C28
# wds:Q6295487-55FCF365-A9FD-4F56-A57D-E76B0DBC2F54
# wds:Q6295487-921A5745-6060-4E5F-8E9E-364E3C6C9F86
# wds:Q6295487-ADD327E2-28F3-454E-B152-A781AC354736
# wds:Q6295853-A4CEC5B4-0C71-48B4-87A9-0AABAAD1AA0C
# wds:Q6295853-F418B608-F95F-43FB-9FA9-811AB1860053
# wds:Q7552806-56B7EA8D-1651-4F5E-B094-26331AB2A113
# wds:Q7552806-95BDBB6D-4CE4-4E07-B0FA-061C56A0CF55
# wds:Q7552806-BE8C8BD1-52A5-4853-A710-C21677E21338
# wds:Q5442869-7BB1424B-01CE-420F-A0CA-9446908723AC
# }
#
#
# ?statement ps:P31 ?instance_of.
# ?qid p:P31 ?statement.
# ?qid rdfs:label ?label.
# filter(lang(?label)='en')
# optional{
# ?statement prov:wasDerivedFrom ?reference.
# ?reference pr:P248 ?statedIn.
# }
# optional{
# ?statement prov:wasDerivedFrom ?reference.
# ?reference pr:P854 ?refUrl.
# }
# optional{
# ?statement prov:wasDerivedFrom ?reference.
# ?reference prv:P813 ?retrievedNode.
# ?retrievedNode wikibase:timeValue ?retrDate.
# ?retrievedNode wikibase:timePrecision ?retrPrecision.
# }
# }

# %%
# send request to Wikidata Query Service
response = requests.post(endpoint, data=query, headers=requestheader)
data = response.json()

# extract the values from the response JSON
results = data['results']['bindings']
results
# Out:
# [{'statement': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/statement/Q50815593-87C17CD1-F50C-4BDE-804C-0AC06F958B37'},
#   'reference': {'type': 'uri',
#    'value': 'http://www.wikidata.org/reference/e544413e0106f7253a231dfffe136d9d9fff837a'},
#   'retrDate': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-05-10T00:00:00Z'},
#   'retrPrecision': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'type': 'literal',
#    'value': '11'},
#   'instance_of': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q773668'},
#   'label': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Journal of French and Francophone Philosophy'},
#   'statedIn': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q1227538'}},
#  {'statement': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/statement/Q50426426-CC1BBEFB-DA93-4EF8-9D9D-899A08417EC2'},
#   'reference': {'type': 'uri',
#    'value': 'http://www.wikidata.org/reference/e544413e0106f7253a231dfffe136d9d9fff837a'},
#   'retrDate': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-05-10T00:00:00Z'},
#   'retrPrecision': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'type': 'literal',
#    'value': '11'},
#   'instance_of': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q773668'},
#   'label': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Estudos de Religião'},
#   'statedIn': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q1227538'}},
#  {'statement': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/statement/Q50814896-FDBA9022-8407-4FCE-BCEE-425E1BFB98CE'},
#   'reference': {'type': 'uri',
#    'value': 'http://www.wikidata.org/reference/e544413e0106f7253a231dfffe136d9d9fff837a'},
#   'retrDate': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-05-10T00:00:00Z'},
#   'retrPrecision': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'type': 'literal',
#    'value': '11'},
#   'instance_of': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q773668'},
#   'label': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Studies in Christian-Jewish Relations'},
#   'statedIn': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q1227538'}},
#  {'statement': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/statement/Q50816836-EFBD79D8-7C43-4471-B319-182E4ECD2013'},
#   'reference': {'type': 'uri',
#    'value': 'http://www.wikidata.org/reference/ec6abbcec5c2eb36253515a228b104f62fa97de7'},
#   'retrDate': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2019-09-22T00:00:00Z'},
#   'retrPrecision': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'type': 'literal',
#    'value': '11'},
#   'instance_of': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q773668'},
#   'label': {'xml:lang': 'en', 'type': 'literal', 'value': 'Podium'},
#   'statedIn': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q1227538'}},
#  {'statement': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/statement/Q50426286-975B042C-A24C-4F39-A802-1746A1D7CE9A'},
#   'reference': {'type': 'uri',
#    'value': 'http://www.wikidata.org/reference/e544413e0106f7253a231dfffe136d9d9fff837a'},
#   'retrDate': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#    'type': 'literal',
#    'value': '2018-05-10T00:00:00Z'},
#   'retrPrecision': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#    'type': 'literal',
#    'value': '11'},
#   'instance_of': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q773668'},
#   'label': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Estudos Teológicos'},
#   'statedIn': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q1227538'}},
#  {'statement': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/statement/Q50478535-4F4A0C8E-7245-4F4F-8C0E-289A66EB7B09'},
#   'reference': {'type': 'uri',
#    'value': 'http://www.wikidata.org/reference
}},
#  {'statement': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/statement/Q2412214-8060602C-4135-44F7-9E1C-3BA073791E53'},
#   'instance_of': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q737498'},
#   'label': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'The Jewish Quarterly Review'}},
#  {'statement': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/statement/Q15761107-92DE30FF-E858-4C62-90EC-83825F4865CA'},
#   'instance_of': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q737498'},
#   'label': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'International Journal of Practical Theology'}},
#  {'statement': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/statement/Q15755037-878D5F21-22BB-4351-A8E4-D91112DE0DB2'},
#   'instance_of': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q737498'},
#   'label': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Jewish Social Studies'}},
#  {'statement': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/statement/Q15750019-1AF9FE8F-7D85-41C2-901F-CCDE8751CDC6'},
#   'instance_of': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q737498'},
#   'label': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Journal of Feminist Studies in Religion'}},
#  {'statement': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/statement/Q15767535-1323199E-0AB9-4F48-B40D-66EDF1806335'},
#   'instance_of': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q737498'},
#   'label': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Journal of the Society of Christian Ethics'}},
#  {'statement': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/statement/Q5442869-7BB1424B-01CE-420F-A0CA-9446908723AC'},
#   'instance_of': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q737498'},
#   'label': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Feminist Theology'}},
#  {'statement': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/statement/Q91678397-5cc36403-4360-14b0-3f4e-879b88125a8c'},
#   'instance_of': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q737498'},
#   'label': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Journal of theology'}},
#  {'statement': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/statement/Q1941982-1AF0C90E-38F4-498A-8467-08B23971E76D'},
#   'instance_of': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q737498'},
#   'label': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Modern Austrian Literature'}},
#  {'statement': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/statement/Q1941982-4E2C05A0-38DF-45CD-92C2-7F57C7AF7810'},
#   'instance_of': {'type': 'uri',
#    'value': 'http://www.wikidata.org/entity/Q1002697'},
#   'label': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Modern Austrian Literature'}}]

# %%
# extract results
references_list = []
for result in results:
    row_dict = {}
    row_dict[property['variable'] + '_uuid'], row_dict['qid'] = extract_statement_uuid(result['statement']['value'])
    row_dict[property['variable']] = result[property['variable']]['value']
    row_dict['label'] = result['label']['value']
    try:
        row_dict[property['variable'] + '_ref1_hash'] = extract_qnumber(result['reference']['value'])
    except:
        row_dict[property['variable'] + '_ref1_hash'] = ''
    try:
        row_dict[property['variable'] + '_ref1_statedIn'] = extract_qnumber(result['statedIn']['value'])
    except:
        row_dict[property['variable'] + '_ref1_statedIn'] = ''
    try:
        row_dict[property['variable'] + '_ref1_referenceUrl'] = result['refUrl']['value']
    except:
        row_dict[property['variable'] + '_ref1_referenceUrl'] = ''
    try:
        row_dict[property['variable'] + '_ref1_retrieved_val'] = result['retrDate']['value']
    except:
        row_dict[property['variable'] + '_ref1_retrieved_val'] = ''
    try:
        row_dict[property['variable'] + '_ref1_retrieved_prec'] = result['retrPrecision']['value']
    except:
        row_dict[property['variable'] + '_ref1_retrieved_prec'] = ''
    references_list.append(row_dict)
    

print(json.dumps(references_list, indent=2))
# Out:
# [
#   {
#     "instance_of_uuid": "87C17CD1-F50C-4BDE-804C-0AC06F958B37",
#     "qid": "Q50815593",
#     "instance_of": "http://www.wikidata.org/entity/Q773668",
#     "label": "Journal of French and Francophone Philosophy",
#     "instance_of_ref1_hash": "e544413e0106f7253a231dfffe136d9d9fff837a",
#     "instance_of_ref1_statedIn": "Q1227538",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "2018-05-10T00:00:00Z",
#     "instance_of_ref1_retrieved_prec": "11"
#   },
#   {
#     "instance_of_uuid": "CC1BBEFB-DA93-4EF8-9D9D-899A08417EC2",
#     "qid": "Q50426426",
#     "instance_of": "http://www.wikidata.org/entity/Q773668",
#     "label": "Estudos de Religi\u00e3o",
#     "instance_of_ref1_hash": "e544413e0106f7253a231dfffe136d9d9fff837a",
#     "instance_of_ref1_statedIn": "Q1227538",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "2018-05-10T00:00:00Z",
#     "instance_of_ref1_retrieved_prec": "11"
#   },
#   {
#     "instance_of_uuid": "FDBA9022-8407-4FCE-BCEE-425E1BFB98CE",
#     "qid": "Q50814896",
#     "instance_of": "http://www.wikidata.org/entity/Q773668",
#     "label": "Studies in Christian-Jewish Relations",
#     "instance_of_ref1_hash": "e544413e0106f7253a231dfffe136d9d9fff837a",
#     "instance_of_ref1_statedIn": "Q1227538",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "2018-05-10T00:00:00Z",
#     "instance_of_ref1_retrieved_prec": "11"
#   },
#   {
#     "instance_of_uuid": "EFBD79D8-7C43-4471-B319-182E4ECD2013",
#     "qid": "Q50816836",
#     "instance_of": "http://www.wikidata.org/entity/Q773668",
#     "label": "Podium",
#     "instance_of_ref1_hash": "ec6abbcec5c2eb36253515a228b104f62fa97de7",
#     "instance_of_ref1_statedIn": "Q1227538",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "2019-09-22T00:00:00Z",
#     "instance_of_ref1_retrieved_prec": "11"
#   },
#   {
#     "instance_of_uuid": "975B042C-A24C-4F39-A802-1746A1D7CE9A",
#     "qid": "Q50426286",
#     "instance_of": "http://www.wikidata.org/entity/Q773668",
#     "label": "Estudos Teol\u00f3gicos",
#     "instance_of_ref1_hash": "e544413e0106f7253a231dfffe136d9d9fff837a",
#     "instance_of_ref1_statedIn": "Q1227538",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "2018-05-10T00:00:00Z",
#     "instance_of_ref1_retrieved_prec": "11"
#   },
#   {
#     "instance_of_uuid": "4F4A0C8E-7245-4F4F-8C0E-289A66EB7B09",
#     "qid": "Q50478535",
#     "instance_of": "http://www.wikidata.org/entity/Q773668",
#     "label": "The Covenant Quarterly",
#     "instance_of_ref1_hash": "e544413e0106f7253a231dfffe136d9d9fff837a",
#     "instance_of_ref1_statedIn": "Q1227538",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "2018-05-10T00:00:00Z",
#     "instance_of_ref1_retrieved_prec": "11"
#   },
#   {
#     "instance_of_uuid": "C571317E-2AA1-429F-89BC-0631B550B7A2",
#     "qid": "Q6294702",
#     "instance_of": "http://www.wikidata.org/entity/Q73364223",
#     "label": "Journal for the Scientific Study of Religion",
#     "instance_of_ref1_hash": "02f18cb56c411ef007701a027c193da838b5e38b",
#     "instance_of_ref1_statedIn": "Q73539606",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "330CE160-8BA0-482C-ACD3-8CDFD5D50BC7",
#     "qid": "Q4041879",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Journal of Biblical Literature",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "A554DB1B-FDE5-485E-BAFB-3DFC35243896",
#     "qid": "Q7311312",
#     "instance_of": "http://www.wikidata.org/entity/Q1002697",
#     "label": "Religious Studies Review",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "A9A1FAC9-1A68-41D0-877B-18C1BC42F690",
#     "qid": "Q7437800",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Scottish Journal of Theology",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "335755ED-59D1-4305-80B5-AEE6D1EB8DBD",
#     "qid": "Q4051386",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Theology Today",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "7A024214-F5CB-425A-B167-4571CA6C7B0A",
#     "qid": "Q63871731",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Liturgy",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "ADD327E2-28F3-454E-B152-A781AC354736",
#     "qid": "Q6295487",
#     "instance_of": "http://www.wikidata.org/entity/Q73364223",
#     "label": "Journal of Marriage and Family",
#     "instance_of_ref1_hash": "874c3a9ab69a051ded5c4fa63d6fd65089ec3799",
#     "instance_of_ref1_statedIn": "Q73539606",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "6DBA517C-50B9-4673-8495-4A083B8B1DE3",
#     "qid": "Q7311115",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Religion",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "FA9BB43D-B7B1-496F-AE5B-39C33AC822FF",
#     "qid": "Q5382167",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Ephemerides Theologicae Lovanienses",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "1ECF040F-D49A-4206-AC3B-DEAF44E76E76",
#     "qid": "Q8075881",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Zygon",
#     "instance_of_ref1_hash": "43ec912f07d5065c548c57b504a5d40cac8baf2b",
#     "instance_of_ref1_statedIn": "Q73539606",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "20760FE6-651D-48AD-B808-B8918B4A8E2F",
#     "qid": "Q15762548",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Ecumenical Review",
#     "instance_of_ref1_hash": "43ec912f07d5065c548c57b504a5d40cac8baf2b",
#     "instance_of_ref1_statedIn": "Q73539606",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "0DFBF7F4-FA31-4F59-A500-65049DAD7D04",
#     "qid": "Q15707782",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Journal of Early Christian Studies",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "3DDF789D-C2D5-4727-9E69-55C800190ACD",
#     "qid": "Q15710287",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Toronto Journal of Theology",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "7CF54B24-7309-469B-AB24-3BE52A9DE517",
#     "qid": "Q15763974",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Review of Biblical Literature",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "60AC1BF3-64BA-44FB-B625-9C15AA1072AD",
#     "qid": "Q15755134",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Theological Education",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "36E0F154-110C-437A-A58F-8D24FA22AF02",
#     "qid": "Q50426426",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Estudos de Religi\u00e3o",
#     "instance_of_ref1_hash": "cfd697a99ce1b4308e5c6bc8c44ce885d5ecf865",
#     "instance_of_ref1_statedIn": "Q1227538",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "41339846-2099-4C73-B55A-A6A618DFCCEE",
#     "qid": "Q15763977",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Perspectives in Religious Studies",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "11E97024-9C01-4317-B877-C9C8574CA30A",
#     "qid": "Q15756294",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Practical Theology",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "127EC1F3-BBF5-4FE5-895C-10F3BD50F322",
#     "qid": "Q15751172",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Race, Ethnicity and Education",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "5EE25FDE-B41B-4CBE-9999-7A0D7684FB16",
#     "qid": "Q15764425",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Sociology of Religion",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "1A25729F-E7BA-4A0E-8207-88A4FC7DD86D",
#     "qid": "Q15762548",
#     "instance_of": "http://www.wikidata.org/entity/Q73364223",
#     "label": "Ecumenical Review",
#     "instance_of_ref1_hash": "1cd942c7976406acdf6e9c10c9498802bd31ea25",
#     "instance_of_ref1_statedIn": "Q73539606",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "6AD43F82-C2BE-4833-9121-41225E64BF29",
#     "qid": "Q50815593",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Journal of French and Francophone Philosophy",
#     "instance_of_ref1_hash": "cfd697a99ce1b4308e5c6bc8c44ce885d5ecf865",
#     "instance_of_ref1_statedIn": "Q1227538",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "CF779D97-7782-4AF9-B84B-7A12FEA49122",
#     "qid": "Q6294702",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Journal for the Scientific Study of Religion",
#     "instance_of_ref1_hash": "43ec912f07d5065c548c57b504a5d40cac8baf2b",
#     "instance_of_ref1_statedIn": "Q73539606",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "ED88700E-7EAB-4315-9BC5-1A6D0A8E8BBB",
#     "qid": "Q7311312",
#     "instance_of": "http://www.wikidata.org/entity/Q73364223",
#     "label": "Religious Studies Review",
#     "instance_of_ref1_hash": "2f0e584d4f76bc296d124f1f9ecd15126cc1ff8b",
#     "instance_of_ref1_statedIn": "Q73539606",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "24511DD8-05D2-40BE-A01E-8EED114066C8",
#     "qid": "Q6087079",
#     "instance_of": "http://www.wikidata.org/entity/Q5633421",
#     "label": "Proceedings of the American Philosophical Society",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "BCFF5533-57BF-4A6D-90F2-936DA8AE2C28",
#     "qid": "Q8075881",
#     "instance_of": "http://www.wikidata.org/entity/Q5633421",
#     "label": "Zygon",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "E9E66F81-0778-4F51-963C-1F88FFC19382",
#     "qid": "Q63871802",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "The Review of Faith & International Affairs",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "BCC47857-027E-4850-B09D-DAE969247D84",
#     "qid": "Q3523724",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Theological Studies",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "28cc57d6-4614-6b50-14a5-1e07a16a1583",
#     "qid": "Q38312865",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "New Directions for Philanthropic Fundraising",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "979F2082-D33B-403C-B43A-2335553C6EB0",
#     "qid": "Q15753995",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Anglican Theological Review",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "A87E87A5-F6A9-4BFC-89BC-54A5A861B8F3",
#     "qid": "Q15749151",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Berliner Theologische Zeitschrift",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "DF665463-9CB2-4F05-A287-D5359512EEF8",
#     "qid": "Q50814896",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Studies in Christian-Jewish Relations",
#     "instance_of_ref1_hash": "cfd697a99ce1b4308e5c6bc8c44ce885d5ecf865",
#     "instance_of_ref1_statedIn": "Q1227538",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "289A2F5E-15CE-4937-9D65-A001B9C69484",
#     "qid": "Q15763357",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "International Journal for Philosophy of Religion",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "41526136-CC12-4047-84BB-276E638268CB",
#     "qid": "Q15716423",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Philosophy Today",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "6331867C-6F5B-441E-9B7D-614A6538F444",
#     "qid": "Q15755905",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Studies in Philology",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "00608960-3EB3-422D-AA48-0870530BD6E0",
#     "qid": "Q5433232",
#     "instance_of": "http://www.wikidata.org/entity/Q73364223",
#     "label": "Family Relations",
#     "instance_of_ref1_hash": "619a61b02fa44b5979ba45ba71b3d068c0839d9b",
#     "instance_of_ref1_statedIn": "Q73539606",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "0AEA6228-3ED9-41EA-808E-D5C1A20708BE",
#     "qid": "Q4903269",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Biblical Theology Bulletin",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "A4CEC5B4-0C71-48B4-87A9-0AABAAD1AA0C",
#     "qid": "Q6295853",
#     "instance_of": "http://www.wikidata.org/entity/Q73364223",
#     "label": "Journal of Religious History",
#     "instance_of_ref1_hash": "8948fb8954a86f640e0472b8f95400b2b2db6a3a",
#     "instance_of_ref1_statedIn": "Q73539606",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "A70C7D66-B68B-46CE-9E2A-B2483778BC4B",
#     "qid": "Q15767635",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Method and Theory in the Study of Religion",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "8B09C503-1498-4C4F-A15E-C819A1AADEFF",
#     "qid": "Q6071283",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Irish Theological Quarterly",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "55FCF365-A9FD-4F56-A57D-E76B0DBC2F54",
#     "qid": "Q6295487",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Journal of Marriage and Family",
#     "instance_of_ref1_hash": "43ec912f07d5065c548c57b504a5d40cac8baf2b",
#     "instance_of_ref1_statedIn": "Q73539606",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "944364C9-23EB-4BEA-966E-7353B879D6CE",
#     "qid": "Q15762548",
#     "instance_of": "http://www.wikidata.org/entity/Q5633421",
#     "label": "Ecumenical Review",
#     "instance_of_ref1_hash": "1643281ef6e577673e4272176fc12a9fcfa37747",
#     "instance_of_ref1_statedIn": "Q15735759",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "49B9C256-464D-49EA-899B-6E46CEB6D5A7",
#     "qid": "Q15751172",
#     "instance_of": "http://www.wikidata.org/entity/Q5633421",
#     "label": "Race, Ethnicity and Education",
#     "instance_of_ref1_hash": "1643281ef6e577673e4272176fc12a9fcfa37747",
#     "instance_of_ref1_statedIn": "Q15735759",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "EC003478-FBE5-4812-B414-868AC673033D",
#     "qid": "Q63871713",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Journal of Pastoral Theology",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "4A2184DC-ABB0-473D-BBCE-31469A8CFD01",
#     "qid": "Q7311312",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Religious Studies Review",
#     "instance_of_ref1_hash": "43ec912f07d5065c548c57b504a5d40cac8baf2b",
#     "instance_of_ref1_statedIn": "Q73539606",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "F418B608-F95F-43FB-9FA9-811AB1860053",
#     "qid": "Q6295853",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Journal of Religious History",
#     "instance_of_ref1_hash": "43ec912f07d5065c548c57b504a5d40cac8baf2b",
#     "instance_of_ref1_statedIn": "Q73539606",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "2F708386-80F0-4BB9-9695-1FB6F3A92A57",
#     "qid": "Q6888892",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Modern Theology",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "CC1E4820-96DE-4407-A197-27F6035697F1",
#     "qid": "Q5433232",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Family Relations",
#     "instance_of_ref1_hash": "43ec912f07d5065c548c57b504a5d40cac8baf2b",
#     "instance_of_ref1_statedIn": "Q73539606",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "921A5745-6060-4E5F-8E9E-364E3C6C9F86",
#     "qid": "Q6295487",
#     "instance_of": "http://www.wikidata.org/entity/Q5633421",
#     "label": "Journal of Marriage and Family",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "91645C5B-2728-4E8E-B1DD-204B6F3D9790",
#     "qid": "Q8075881",
#     "instance_of": "http://www.wikidata.org/entity/Q73364223",
#     "label": "Zygon",
#     "instance_of_ref1_hash": "db4b18593ff065d408de6a2ed7d9cdc3fedc0856",
#     "instance_of_ref1_statedIn": "Q73539606",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "524F3A33-FD71-47D6-84A6-2C4E008B4BF0",
#     "qid": "Q68836075",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Social Problems",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "675D08EB-5691-48D5-9741-6A3D796862F8",
#     "qid": "Q15763031",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Modern Judaism",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "A3C798F2-297B-41B8-A44E-B51678E43752",
#     "qid": "Q15759717",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Review of Politics",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "BD770C01-0461-4953-B917-F843770DD7F4",
#     "qid": "Q15817868",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "East European Jewish Affairs",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "6BAA40A0-30AD-4FBC-B06B-0E927F50E956",
#     "qid": "Q57615071",
#     "instance_of": "http://www.wikidata.org/entity/Q685935",
#     "label": "Critical Research on Religion",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "4ECB0BE4-8E89-4B3F-BC59-7D9CDDF13144",
#     "qid": "Q57615071",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Critical Research on Religion",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "F23481FD-CAAD-423A-A04D-006A629AB2A9",
#     "qid": "Q57615071",
#     "instance_of": "http://www.wikidata.org/entity/Q5633421",
#     "label": "Critical Research on Religion",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "446CB56E-E753-4D42-99C6-0E5BFB253C9B",
#     "qid": "Q5024509",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Calvin Theological Journal",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "42D3081E-A7B7-4558-ADA9-E8F5BA2BD591",
#     "qid": "Q5676604",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Harvard Theological Review",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "D1267AAF-2363-4D8C-B395-0BADD949902E",
#     "qid": "Q50432461",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Nederduitse Gereformeerde Teologiese Tydskrif",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "56B7EA8D-1651-4F5E-B094-26331AB2A113",
#     "qid": "Q7552806",
#     "instance_of": "http://www.wikidata.org/entity/Q5633421",
#     "label": "Sociological Inquiry",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "689B4A19-F3D7-4A7F-977F-9033AB9C7E33",
#     "qid": "Q7628082",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Studies in World Christianity",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "6001D5EF-49B7-4F5D-8040-1AE433FCB2E5",
#     "qid": "Q15710071",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Journal of the American Academy of Religion",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "735CC0AB-754A-49FE-8FF1-22799E2D58CE",
#     "qid": "Q88977207",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Women, Gender, and Families of Color",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "2CA54E40-2E97-4D5A-98AF-F445B278CA05",
#     "qid": "Q15754942",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "American Journal of Theology and Philosophy",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "717BF0F1-11B7-4E18-82D5-A1FB26DD3CFA",
#     "qid": "Q15754681",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Horizons in Biblical Theology",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "B46566B2-0A27-4D21-B4BA-452C1A205229",
#     "qid": "Q15755002",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Political Theology",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "34E7251F-2560-44A9-9B07-69725A16D67B",
#     "qid": "Q15762047",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Review of Religious Research",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "C00CDF4C-DD0E-42B3-8C43-594569C8B670",
#     "qid": "Q15746447",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "The Bible Today",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "83586CB7-1672-447E-A9C1-CE3D4DE88E18",
#     "qid": "Q50426286",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Estudos Teol\u00f3gicos",
#     "instance_of_ref1_hash": "cfd697a99ce1b4308e5c6bc8c44ce885d5ecf865",
#     "instance_of_ref1_statedIn": "Q1227538",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "C2B48F12-C5E8-4CD4-B20A-845176E3FD5D",
#     "qid": "Q15816830",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Black Theology",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "C54C6D72-0736-4BFE-B73D-65BC886C82C2",
#     "qid": "Q18350356",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Humanity & Society",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "13818A8D-69F9-4B4F-9E59-FFFF044B43F7",
#     "qid": "Q50478535",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "The Covenant Quarterly",
#     "instance_of_ref1_hash": "cfd697a99ce1b4308e5c6bc8c44ce885d5ecf865",
#     "instance_of_ref1_statedIn": "Q1227538",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "5CF667AE-F364-4CFC-A9DB-9F102C076522",
#     "qid": "Q6087079",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Proceedings of the American Philosophical Society",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "6E7D1159-D02B-43DB-A9E0-EE384C30BBD5",
#     "qid": "Q2412214",
#     "instance_of": "http://www.wikidata.org/entity/Q41298",
#     "label": "The Jewish Quarterly Review",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "49ED8A3A-39C9-490B-95DB-0CCA0A82705F",
#     "qid": "Q5158991",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Concordia Theological Quarterly",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "674BC569-ACCB-4CB5-84D3-AAD422F8480A",
#     "qid": "Q15760154",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Journal of Religious Ethics",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "99948E12-C1AB-467E-B3CD-A7D6AE236E3B",
#     "qid": "Q15755692",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Journal of the European Society of Women in Theological Research",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "8449F2E1-2065-4E2A-AEEA-4DB71DFE4D1E",
#     "qid": "Q15716275",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Neue Zeitschrift fuer Systematische Theologie und Religionsphilosophie",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "371E5DDE-6049-49EE-810D-7AB5BB8E12A1",
#     "qid": "Q15716715",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Notre Dame Philosophical Reviews",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "95BDBB6D-4CE4-4E07-B0FA-061C56A0CF55",
#     "qid": "Q7552806",
#     "instance_of": "http://www.wikidata.org/entity/Q73364223",
#     "label": "Sociological Inquiry",
#     "instance_of_ref1_hash": "b752a7af84ea21690d341237c4c6c9e1612c54b7",
#     "instance_of_ref1_statedIn": "Q73539606",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "D2065196-3273-4B99-8CC5-45B9569EA121",
#     "qid": "Q4041903",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "The Journal of Theological Studies",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "0D280C1D-8113-489E-8936-373EA0E2700E",
#     "qid": "Q50816836",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Podium",
#     "instance_of_ref1_hash": "cfd697a99ce1b4308e5c6bc8c44ce885d5ecf865",
#     "instance_of_ref1_statedIn": "Q1227538",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "29E10050-C12A-48CC-B06A-B953AFFB8B4D",
#     "qid": "Q18392457",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Spring",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "721E1B7D-B056-4991-8792-1603907690D0",
#     "qid": "Q4984286",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Buddhist\u2013Christian Studies",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "BE8C8BD1-52A5-4853-A710-C21677E21338",
#     "qid": "Q7552806",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Sociological Inquiry",
#     "instance_of_ref1_hash": "43ec912f07d5065c548c57b504a5d40cac8baf2b",
#     "instance_of_ref1_statedIn": "Q73539606",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "49CEBE44-564F-4FC1-B9FE-FC080ABA5D2D",
#     "qid": "Q7743622",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "The Journal of Religion",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "5F932FD0-87F4-4B61-85B1-92A22803EAFA",
#     "qid": "Q15749660",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Religion Compass",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "6FC177B7-1F8B-48F6-B1A8-70B027449215",
#     "qid": "Q15816920",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Bulletin for the Study of Religion",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "80C4942D-123A-46CB-BF81-A25A6B00C307",
#     "qid": "Q62259203",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Journal of Africana Religions",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "84233062-36AE-48E7-9D89-EC93EA6EFE05",
#     "qid": "Q7989227",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Westminster Theological Journal",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "6E280AAE-1E0B-45B8-8F7B-32B3ECA5FF34",
#     "qid": "Q62259203",
#     "instance_of": "http://www.wikidata.org/entity/Q5633421",
#     "label": "Journal of Africana Religions",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "8060602C-4135-44F7-9E1C-3BA073791E53",
#     "qid": "Q2412214",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "The Jewish Quarterly Review",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "92DE30FF-E858-4C62-90EC-83825F4865CA",
#     "qid": "Q15761107",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "International Journal of Practical Theology",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "878D5F21-22BB-4351-A8E4-D91112DE0DB2",
#     "qid": "Q15755037",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Jewish Social Studies",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "1AF9FE8F-7D85-41C2-901F-CCDE8751CDC6",
#     "qid": "Q15750019",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Journal of Feminist Studies in Religion",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "1323199E-0AB9-4F48-B40D-66EDF1806335",
#     "qid": "Q15767535",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Journal of the Society of Christian Ethics",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "7BB1424B-01CE-420F-A0CA-9446908723AC",
#     "qid": "Q5442869",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Feminist Theology",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "5cc36403-4360-14b0-3f4e-879b88125a8c",
#     "qid": "Q91678397",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Journal of theology",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "1AF0C90E-38F4-498A-8467-08B23971E76D",
#     "qid": "Q1941982",
#     "instance_of": "http://www.wikidata.org/entity/Q737498",
#     "label": "Modern Austrian Literature",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   },
#   {
#     "instance_of_uuid": "4E2C05A0-38DF-45CD-92C2-7F57C7AF7810",
#     "qid": "Q1941982",
#     "instance_of": "http://www.wikidata.org/entity/Q1002697",
#     "label": "Modern Austrian Literature",
#     "instance_of_ref1_hash": "",
#     "instance_of_ref1_statedIn": "",
#     "instance_of_ref1_referenceUrl": "",
#     "instance_of_ref1_retrieved_val": "",
#     "instance_of_ref1_retrieved_prec": ""
#   }
# ]

# %%
# create the list of column headers
fieldnames = ['qid', property['variable'] + '_uuid', property['variable'], property['variable'] + '_ref1_hash', property['variable'] + '_ref1_statedIn', property['variable'] + '_ref1_referenceUrl', property['variable'] + '_ref1_retrieved_val', property['variable'] + '_ref1_retrieved_prec', 'label']

# write the data to a CSV file
print('writing data to file')
vbc.writeDictsToCsv(references_list, home + '/divinity-law/test-journal-instanceof.csv', fieldnames)

print('done')
